# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import sklearn
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.preprocessing import sequence
from keras import metrics 
from sklearn.model_selection import StratifiedKFold
from livelossplot import PlotLossesKeras


NORMAL_INPUT_DATA_DIR = "./split_data/normal/"

# normal_files = []

# for (dirpath, dirnames, filenames) in os.walk(NORMAL_INPUT_DATA_DIR):
#     normal_files.extend(filenames)
#     break
# print(normal_files)
# Out:
# ['data10_normal.csv', 'data11_normal.csv', 'data12_normal.csv', 'data13_normal.csv', 'data14_normal.csv', 'data15_normal.csv', 'data16_normal.csv', 'data17_normal.csv', 'data18_normal.csv', 'data19_normal.csv', 'data1_normal.csv', 'data20_normal.csv', 'data21_normal.csv', 'data22_normal.csv', 'data23_normal.csv', 'data24_normal.csv', 'data25_normal.csv', 'data26_normal.csv', 'data27_normal.csv', 'data28_normal.csv', 'data29_normal.csv', 'data2_normal.csv', 'data30_normal.csv', 'data31_normal.csv', 'data32_normal.csv', 'data33_normal.csv', 'data34_normal.csv', 'data35_normal.csv', 'data36_normal.csv', 'data37_normal.csv', 'data38_normal.csv', 'data39_normal.csv', 'data3_normal.csv', 'data40_normal.csv', 'data41_normal.csv', 'data42_normal.csv', 'data43_normal.csv', 'data44_normal.csv', 'data45_normal.csv', 'data46_normal.csv', 'data47_normal.csv', 'data48_normal.csv', 'data49_normal.csv', 'data4_normal.csv', 'data50_normal.csv', 'data51_normal.csv', 'data52_normal.csv', 'data53_normal.csv', 'data5_normal.csv', 'data6_normal.csv', 'data7_normal.csv', 'data8_normal.csv', 'data9_normal.csv', 'desktop.ini']

# %%
FAULT_INPUT_DATA_DIR = "./split_data/fault/"

# fault_files = []

# for (dirpath, dirnames, filenames) in os.walk(FAULT_INPUT_DATA_DIR):
#     fault_files.extend(filenames)
#     break
# print(fault_files)
# Out:
# ['data10_fault.csv', 'data11_fault.csv', 'data12_fault.csv', 'data13_fault.csv', 'data14_fault.csv', 'data15_fault.csv', 'data16_fault.csv', 'data17_fault.csv', 'data18_fault.csv', 'data19_fault.csv', 'data1_fault.csv', 'data20_fault.csv', 'data21_fault.csv', 'data22_fault.csv', 'data23_fault.csv', 'data24_fault.csv', 'data25_fault.csv', 'data26_fault.csv', 'data27_fault.csv', 'data28_fault.csv', 'data29_fault.csv', 'data2_fault.csv', 'data30_fault.csv', 'data31_fault.csv', 'data32_fault.csv', 'data33_fault.csv', 'data34_fault.csv', 'data35_fault.csv', 'data36_fault.csv', 'data37_fault.csv', 'data38_fault.csv', 'data39_fault.csv', 'data3_fault.csv', 'data40_fault.csv', 'data41_fault.csv', 'data42_fault.csv', 'data43_fault.csv', 'data44_fault.csv', 'data45_fault.csv', 'data46_fault.csv', 'data47_fault.csv', 'data48_fault.csv', 'data49_fault.csv', 'data4_fault.csv', 'data50_fault.csv', 'data51_fault.csv', 'data52_fault.csv', 'data53_fault.csv', 'data54_fault.csv', 'data5_fault.csv', 'data6_fault.csv', 'data7_fault.csv', 'data8_fault.csv', 'data9_fault.csv']

# %%
def get_data(intput_dir):
    data = []

    for (dirpath, dirnames, filenames) in os.walk(intput_dir):
        for filename in filenames:
            try:
                path = intput_dir+"/" + filename
                frame = pd.read_csv(path, header=None)
#                 print(frame)
                if frame.to_numpy().shape == (31,10):
                    data.append(frame.to_numpy().tolist())
            except :
                 print("An exception occurred")
        
    return np.array(data)[:,:,1:10]

# %%
# normal_data = get_data(NORMAL_INPUT_DATA_DIR)
# fault_data = get_data(FAULT_INPUT_DATA_DIR)
# print(normal_data.shape)
# print(fault_data.shape)
# # print(normal_data[0][0])
# Out:
# An exception occurred
# (53, 31, 9)
# (54, 31, 9)

# %%
# dataset = np.concatenate((normal_data, fault_data))
# print(dataset.shape)
# X_train = sequence.pad_sequences(dataset, maxlen=31)
# targets = np.concatenate((np.zeros(len(normal_data)), np.ones(len(fault_data))))
# print(targets.shape)
# Out:
# (107, 31, 9)
# (107,)

# %%
# n_timesteps=31
# n_features=9
# n_outputs=1

# model = Sequential()
# model.add(LSTM(100, input_shape=(n_timesteps,n_features)))
# model.add(Dropout(0.5))
# model.add(Dense(100, activation='relu'))
# model.add(Dense(n_outputs, activation='sigmoid'))
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


# model.fit(dataset, targets, epochs=400, batch_size=4, verbose=2)

# %%
# Out:
# Epoch 1/400
# 27/27 - 1s - loss: 0.7011 - accuracy: 0.5327 - 934ms/epoch - 35ms/step
# Epoch 2/400
# 27/27 - 0s - loss: 0.7122 - accuracy: 0.5047 - 79ms/epoch - 3ms/step
# Epoch 3/400
# 27/27 - 0s - loss: 0.6829 - accuracy: 0.5514 - 73ms/epoch - 3ms/step
# Epoch 4/400
# 27/27 - 0s - loss: 0.6318 - accuracy: 0.6355 - 76ms/epoch - 3ms/step
# Epoch 5/400
# 27/27 - 0s - loss: 0.6733 - accuracy: 0.6075 - 76ms/epoch - 3ms/step
# Epoch 6/400
# 27/27 - 0s - loss: 0.6639 - accuracy: 0.6636 - 76ms/epoch - 3ms/step
# Epoch 7/400
# 27/27 - 0s - loss: 0.6442 - accuracy: 0.6168 - 76ms/epoch - 3ms/step
# Epoch 8/400
# 27/27 - 0s - loss: 0.6620 - accuracy: 0.6262 - 77ms/epoch - 3ms/step
# Epoch 9/400
# 27/27 - 0s - loss: 0.6434 - accuracy: 0.6262 - 76ms/epoch - 3ms/step
# Epoch 10/400
# 27/27 - 0s - loss: 0.6112 - accuracy: 0.6729 - 77ms/epoch - 3ms/step
# Epoch 11/400
# 27/27 - 0s - loss: 0.6145 - accuracy: 0.6636 - 78ms/epoch - 3ms/step
# Epoch 12/400
# 27/27 - 0s - loss: 0.6050 - accuracy: 0.6542 - 78ms/epoch - 3ms/step
# Epoch 13/400
# 27/27 - 0s - loss: 0.6499 - accuracy: 0.5701 - 76ms/epoch - 3ms/step
# Epoch 14/400
# 27/27 - 0s - loss: 0.6305 - accuracy: 0.6636 - 75ms/epoch - 3ms/step
# Epoch 15/400
# 27/27 - 0s - loss: 0.7154 - accuracy: 0.5514 - 75ms/epoch - 3ms/step
# Epoch 16/400
# 27/27 - 0s - loss: 0.6318 - accuracy: 0.6262 - 75ms/epoch - 3ms/step
# Epoch 17/400
# 27/27 - 0s - loss: 0.6205 - accuracy: 0.6449 - 74ms/epoch - 3ms/step
# Epoch 18/400
# 27/27 - 0s - loss: 0.6266 - accuracy: 0.6168 - 74ms/epoch - 3ms/step
# Epoch 19/400
# 27/27 - 0s - loss: 0.6518 - accuracy: 0.5981 - 75ms/epoch - 3ms/step
# Epoch 20/400
# 27/27 - 0s - loss: 0.5903 - accuracy: 0.6822 - 76ms/epoch - 3ms/step
# Epoch 21/400
# 27/27 - 0s - loss: 0.6176 - accuracy: 0.6355 - 73ms/epoch - 3ms/step
# Epoch 22/400
# 27/27 - 0s - loss: 0.6409 - accuracy: 0.6168 - 75ms/epoch - 3ms/step
# Epoch 23/400
# 27/27 - 0s - loss: 0.6075 - accuracy: 0.6729 - 76ms/epoch - 3ms/step
# Epoch 24/400
# 27/27 - 0s - loss: 0.6397 - accuracy: 0.6449 - 79ms/epoch - 3ms/step
# Epoch 25/400
# 27/27 - 0s - loss: 0.5619 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 26/400
# 27/27 - 0s - loss: 0.5561 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 27/400
# 27/27 - 0s - loss: 0.5931 - accuracy: 0.6636 - 76ms/epoch - 3ms/step
# Epoch 28/400
# 27/27 - 0s - loss: 0.5421 - accuracy: 0.7477 - 77ms/epoch - 3ms/step
# Epoch 29/400
# 27/27 - 0s - loss: 0.5664 - accuracy: 0.7009 - 73ms/epoch - 3ms/step
# Epoch 30/400
# 27/27 - 0s - loss: 0.6435 - accuracy: 0.6542 - 73ms/epoch - 3ms/step
# Epoch 31/400
# 27/27 - 0s - loss: 0.6185 - accuracy: 0.6355 - 76ms/epoch - 3ms/step
# Epoch 32/400
# 27/27 - 0s - loss: 0.6106 - accuracy: 0.6542 - 77ms/epoch - 3ms/step
# Epoch 33/400
# 27/27 - 0s - loss: 0.6331 - accuracy: 0.6449 - 75ms/epoch - 3ms/step
# Epoch 34/400
# 27/27 - 0s - loss: 0.5708 - accuracy: 0.6449 - 78ms/epoch - 3ms/step
# Epoch 35/400
# 27/27 - 0s - loss: 0.5864 - accuracy: 0.7196 - 75ms/epoch - 3ms/step
# Epoch 36/400
# 27/27 - 0s - loss: 0.5920 - accuracy: 0.6636 - 73ms/epoch - 3ms/step
# Epoch 37/400
# 27/27 - 0s - loss: 0.5803 - accuracy: 0.6916 - 77ms/epoch - 3ms/step
# Epoch 38/400
# 27/27 - 0s - loss: 0.5824 - accuracy: 0.6636 - 77ms/epoch - 3ms/step
# Epoch 39/400
# 27/27 - 0s - loss: 0.5902 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 40/400
# 27/27 - 0s - loss: 0.5213 - accuracy: 0.7757 - 75ms/epoch - 3ms/step
# Epoch 41/400
# 27/27 - 0s - loss: 0.5566 - accuracy: 0.7009 - 72ms/epoch - 3ms/step
# Epoch 42/400
# 27/27 - 0s - loss: 0.5591 - accuracy: 0.6916 - 76ms/epoch - 3ms/step
# Epoch 43/400
# 27/27 - 0s - loss: 0.5479 - accuracy: 0.7103 - 75ms/epoch - 3ms/step
# Epoch 44/400
# 27/27 - 0s - loss: 0.5125 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 45/400
# 27/27 - 0s - loss: 0.5719 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 46/400
# 27/27 - 0s - loss: 0.5614 - accuracy: 0.7196 - 75ms/epoch - 3ms/step
# Epoch 47/400
# 27/27 - 0s - loss: 0.5707 - accuracy: 0.7383 - 72ms/epoch - 3ms/step
# Epoch 48/400
# 27/27 - 0s - loss: 0.5610 - accuracy: 0.7383 - 74ms/epoch - 3ms/step
# Epoch 49/400
# 27/27 - 0s - loss: 0.5572 - accuracy: 0.7383 - 78ms/epoch - 3ms/step
# Epoch 50/400
# 27/27 - 0s - loss: 0.5741 - accuracy: 0.6822 - 75ms/epoch - 3ms/step
# Epoch 51/400
# 27/27 - 0s - loss: 0.5196 - accuracy: 0.7103 - 78ms/epoch - 3ms/step
# Epoch 52/400
# 27/27 - 0s - loss: 0.5385 - accuracy: 0.7103 - 77ms/epoch - 3ms/step
# Epoch 53/400
# 27/27 - 0s - loss: 0.5710 - accuracy: 0.7103 - 74ms/epoch - 3ms/step
# Epoch 54/400
# 27/27 - 0s - loss: 0.5556 - accuracy: 0.6916 - 75ms/epoch - 3ms/step
# Epoch 55/400
# 27/27 - 0s - loss: 0.5187 - accuracy: 0.7664 - 74ms/epoch - 3ms/step
# Epoch 56/400
# 27/27 - 0s - loss: 0.5346 - accuracy: 0.7103 - 72ms/epoch - 3ms/step
# Epoch 57/400
# 27/27 - 0s - loss: 0.5297 - accuracy: 0.7009 - 73ms/epoch - 3ms/step
# Epoch 58/400
# 27/27 - 0s - loss: 0.4860 - accuracy: 0.7664 - 75ms/epoch - 3ms/step
# Epoch 59/400
# 27/27 - 0s - loss: 0.5783 - accuracy: 0.6449 - 74ms/epoch - 3ms/step
# Epoch 60/400
# 27/27 - 0s - loss: 0.6460 - accuracy: 0.6262 - 74ms/epoch - 3ms/step
# Epoch 61/400
# 27/27 - 0s - loss: 0.5360 - accuracy: 0.7196 - 74ms/epoch - 3ms/step
# Epoch 62/400
# 27/27 - 0s - loss: 0.5506 - accuracy: 0.7196 - 76ms/epoch - 3ms/step
# Epoch 63/400
# 27/27 - 0s - loss: 0.5877 - accuracy: 0.7103 - 77ms/epoch - 3ms/step
# Epoch 64/400
# 27/27 - 0s - loss: 0.5247 - accuracy: 0.7290 - 74ms/epoch - 3ms/step
# Epoch 65/400
# 27/27 - 0s - loss: 0.5918 - accuracy: 0.6916 - 75ms/epoch - 3ms/step
# Epoch 66/400
# 27/27 - 0s - loss: 0.5377 - accuracy: 0.6916 - 74ms/epoch - 3ms/step
# Epoch 67/400
# 27/27 - 0s - loss: 0.5499 - accuracy: 0.6636 - 74ms/epoch - 3ms/step
# Epoch 68/400
# 27/27 - 0s - loss: 0.5415 - accuracy: 0.6916 - 77ms/epoch - 3ms/step
# Epoch 69/400
# 27/27 - 0s - loss: 0.4808 - accuracy: 0.8224 - 75ms/epoch - 3ms/step
# Epoch 70/400
# 27/27 - 0s - loss: 0.5163 - accuracy: 0.7196 - 75ms/epoch - 3ms/step
# Epoch 71/400
# 27/27 - 0s - loss: 0.4796 - accuracy: 0.7757 - 74ms/epoch - 3ms/step
# Epoch 72/400
# 27/27 - 0s - loss: 0.5247 - accuracy: 0.7383 - 79ms/epoch - 3ms/step
# Epoch 73/400
# 27/27 - 0s - loss: 0.5532 - accuracy: 0.7009 - 78ms/epoch - 3ms/step
# Epoch 74/400
# 27/27 - 0s - loss: 0.4979 - accuracy: 0.7196 - 75ms/epoch - 3ms/step
# Epoch 75/400
# 27/27 - 0s - loss: 0.5313 - accuracy: 0.6729 - 77ms/epoch - 3ms/step
# Epoch 76/400
# 27/27 - 0s - loss: 0.5318 - accuracy: 0.7196 - 74ms/epoch - 3ms/step
# Epoch 77/400
# 27/27 - 0s - loss: 0.5322 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 78/400
# 27/27 - 0s - loss: 0.5398 - accuracy: 0.7944 - 77ms/epoch - 3ms/step
# Epoch 79/400
# 27/27 - 0s - loss: 0.5580 - accuracy: 0.7009 - 76ms/epoch - 3ms/step
# Epoch 80/400
# 27/27 - 0s - loss: 0.6024 - accuracy: 0.6822 - 77ms/epoch - 3ms/step
# Epoch 81/400
# 27/27 - 0s - loss: 0.5134 - accuracy: 0.6822 - 74ms/epoch - 3ms/step
# Epoch 82/400
# 27/27 - 0s - loss: 0.5665 - accuracy: 0.6916 - 75ms/epoch - 3ms/step
# Epoch 83/400
# 27/27 - 0s - loss: 0.5387 - accuracy: 0.7196 - 82ms/epoch - 3ms/step
# Epoch 84/400
# 27/27 - 0s - loss: 0.5116 - accuracy: 0.7383 - 90ms/epoch - 3ms/step
# Epoch 85/400
# 27/27 - 0s - loss: 0.5307 - accuracy: 0.6822 - 74ms/epoch - 3ms/step
# Epoch 86/400
# 27/27 - 0s - loss: 0.5494 - accuracy: 0.7103 - 75ms/epoch - 3ms/step
# Epoch 87/400
# 27/27 - 0s - loss: 0.5191 - accuracy: 0.7196 - 74ms/epoch - 3ms/step
# Epoch 88/400
# 27/27 - 0s - loss: 0.4924 - accuracy: 0.7477 - 75ms/epoch - 3ms/step
# Epoch 89/400
# 27/27 - 0s - loss: 0.5248 - accuracy: 0.7383 - 75ms/epoch - 3ms/step
# Epoch 90/400
# 27/27 - 0s - loss: 0.5314 - accuracy: 0.7009 - 75ms/epoch - 3ms/step
# Epoch 91/400
# 27/27 - 0s - loss: 0.4281 - accuracy: 0.7944 - 73ms/epoch - 3ms/step
# Epoch 92/400
# 27/27 - 0s - loss: 0.5967 - accuracy: 0.6916 - 74ms/epoch - 3ms/step
# Epoch 93/400
# 27/27 - 0s - loss: 0.5130 - accuracy: 0.7944 - 77ms/epoch - 3ms/step
# Epoch 94/400
# 27/27 - 0s - loss: 0.4856 - accuracy: 0.7103 - 77ms/epoch - 3ms/step
# Epoch 95/400
# 27/27 - 0s - loss: 0.4865 - accuracy: 0.7477 - 74ms/epoch - 3ms/step
# Epoch 96/400
# 27/27 - 0s - loss: 0.5153 - accuracy: 0.7103 - 74ms/epoch - 3ms/step
# Epoch 97/400
# 27/27 - 0s - loss: 0.4835 - accuracy: 0.7477 - 75ms/epoch - 3ms/step
# Epoch 98/400
# 27/27 - 0s - loss: 0.4676 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 99/400
# 27/27 - 0s - loss: 0.5150 - accuracy: 0.7383 - 76ms/epoch - 3ms/step
# Epoch 100/400
# 27/27 - 0s - loss: 0.5346 - accuracy: 0.6916 - 76ms/epoch - 3ms/step
# Epoch 101/400
# 27/27 - 0s - loss: 0.4725 - accuracy: 0.7664 - 77ms/epoch - 3ms/step
# Epoch 102/400
# 27/27 - 0s - loss: 0.5428 - accuracy: 0.7290 - 78ms/epoch - 3ms/step
# Epoch 103/400
# 27/27 - 0s - loss: 0.4876 - accuracy: 0.7664 - 77ms/epoch - 3ms/step
# Epoch 104/400
# 27/27 - 0s - loss: 0.5142 - accuracy: 0.7383 - 75ms/epoch - 3ms/step
# Epoch 105/400
# 27/27 - 0s - loss: 0.5232 - accuracy: 0.6916 - 76ms/epoch - 3ms/step
# Epoch 106/400
# 27/27 - 0s - loss: 0.4788 - accuracy: 0.7664 - 76ms/epoch - 3ms/step
# Epoch 107/400
# 27/27 - 0s - loss: 0.4720 - accuracy: 0.7477 - 76ms/epoch - 3ms/step
# Epoch 108/400
# 27/27 - 0s - loss: 0.4854 - accuracy: 0.7196 - 80ms/epoch - 3ms/step
# Epoch 109/400
# 27/27 - 0s - loss: 0.5037 - accuracy: 0.7383 - 77ms/epoch - 3ms/step
# Epoch 110/400
# 27/27 - 0s - loss: 0.5650 - accuracy: 0.7009 - 75ms/epoch - 3ms/step
# Epoch 111/400
# 27/27 - 0s - loss: 0.4475 - accuracy: 0.7944 - 76ms/epoch - 3ms/step
# Epoch 112/400
# 27/27 - 0s - loss: 0.5055 - accuracy: 0.7477 - 75ms/epoch - 3ms/step
# Epoch 113/400
# 27/27 - 0s - loss: 0.4888 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 114/400
# 27/27 - 0s - loss: 0.5867 - accuracy: 0.6916 - 77ms/epoch - 3ms/step
# Epoch 115/400
# 27/27 - 0s - loss: 0.4490 - accuracy: 0.7664 - 78ms/epoch - 3ms/step
# Epoch 116/400
# 27/27 - 0s - loss: 0.4561 - accuracy: 0.7664 - 76ms/epoch - 3ms/step
# Epoch 117/400
# 27/27 - 0s - loss: 0.4897 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 118/400
# 27/27 - 0s - loss: 0.4640 - accuracy: 0.7944 - 74ms/epoch - 3ms/step
# Epoch 119/400
# 27/27 - 0s - loss: 0.4869 - accuracy: 0.7196 - 77ms/epoch - 3ms/step
# Epoch 120/400
# 27/27 - 0s - loss: 0.4842 - accuracy: 0.7850 - 76ms/epoch - 3ms/step
# Epoch 121/400
# 27/27 - 0s - loss: 0.5673 - accuracy: 0.6636 - 76ms/epoch - 3ms/step
# Epoch 122/400
# 27/27 - 0s - loss: 0.4415 - accuracy: 0.7570 - 75ms/epoch - 3ms/step
# Epoch 123/400
# 27/27 - 0s - loss: 0.4700 - accuracy: 0.7757 - 76ms/epoch - 3ms/step
# Epoch 124/400
# 27/27 - 0s - loss: 0.4447 - accuracy: 0.7757 - 75ms/epoch - 3ms/step
# Epoch 125/400
# 27/27 - 0s - loss: 0.4537 - accuracy: 0.7664 - 77ms/epoch - 3ms/step
# Epoch 126/400
# 27/27 - 0s - loss: 0.4976 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 127/400
# 27/27 - 0s - loss: 0.4890 - accuracy: 0.7477 - 76ms/epoch - 3ms/step
# Epoch 128/400
# 27/27 - 0s - loss: 0.4513 - accuracy: 0.7570 - 76ms/epoch - 3ms/step
# Epoch 129/400
# 27/27 - 0s - loss: 0.4367 - accuracy: 0.7850 - 72ms/epoch - 3ms/step
# Epoch 130/400
# 27/27 - 0s - loss: 0.4628 - accuracy: 0.7290 - 74ms/epoch - 3ms/step
# Epoch 131/400
# 27/27 - 0s - loss: 0.5390 - accuracy: 0.7009 - 75ms/epoch - 3ms/step
# Epoch 132/400
# 27/27 - 0s - loss: 0.4760 - accuracy: 0.7383 - 76ms/epoch - 3ms/step
# Epoch 133/400
# 27/27 - 0s - loss: 0.4327 - accuracy: 0.7757 - 74ms/epoch - 3ms/step
# Epoch 134/400
# 27/27 - 0s - loss: 0.3880 - accuracy: 0.8131 - 76ms/epoch - 3ms/step
# Epoch 135/400
# 27/27 - 0s - loss: 0.4881 - accuracy: 0.7290 - 73ms/epoch - 3ms/step
# Epoch 136/400
# 27/27 - 0s - loss: 0.4848 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 137/400
# 27/27 - 0s - loss: 0.4472 - accuracy: 0.7477 - 78ms/epoch - 3ms/step
# Epoch 138/400
# 27/27 - 0s - loss: 0.5270 - accuracy: 0.7103 - 76ms/epoch - 3ms/step
# Epoch 139/400
# 27/27 - 0s - loss: 0.4388 - accuracy: 0.7664 - 73ms/epoch - 3ms/step
# Epoch 140/400
# 27/27 - 0s - loss: 0.4503 - accuracy: 0.7944 - 75ms/epoch - 3ms/step
# Epoch 141/400
# 27/27 - 0s - loss: 0.4582 - accuracy: 0.7944 - 73ms/epoch - 3ms/step
# Epoch 142/400
# 27/27 - 0s - loss: 0.4252 - accuracy: 0.7944 - 73ms/epoch - 3ms/step
# Epoch 143/400
# 27/27 - 0s - loss: 0.4550 - accuracy: 0.7757 - 73ms/epoch - 3ms/step
# Epoch 144/400
# 27/27 - 0s - loss: 0.4497 - accuracy: 0.7383 - 75ms/epoch - 3ms/step
# Epoch 145/400
# 27/27 - 0s - loss: 0.4276 - accuracy: 0.7944 - 75ms/epoch - 3ms/step
# Epoch 146/400
# 27/27 - 0s - loss: 0.4404 - accuracy: 0.7664 - 75ms/epoch - 3ms/step
# Epoch 147/400
# 27/27 - 0s - loss: 0.4406 - accuracy: 0.7383 - 74ms/epoch - 3ms/step
# Epoch 148/400
# 27/27 - 0s - loss: 0.4738 - accuracy: 0.7757 - 73ms/epoch - 3ms/step
# Epoch 149/400
# 27/27 - 0s - loss: 0.4877 - accuracy: 0.7477 - 75ms/epoch - 3ms/step
# Epoch 150/400
# 27/27 - 0s - loss: 0.4526 - accuracy: 0.8131 - 72ms/epoch - 3ms/step
# Epoch 151/400
# 27/27 - 0s - loss: 0.4615 - accuracy: 0.7383 - 75ms/epoch - 3ms/step
# Epoch 152/400
# 27/27 - 0s - loss: 0.4717 - accuracy: 0.7383 - 73ms/epoch - 3ms/step
# Epoch 153/400
# 27/27 - 0s - loss: 0.4222 - accuracy: 0.8037 - 73ms/epoch - 3ms/step
# Epoch 154/400
# 27/27 - 0s - loss: 0.5233 - accuracy: 0.7196 - 75ms/epoch - 3ms/step
# Epoch 155/400
# 27/27 - 0s - loss: 0.4324 - accuracy: 0.7290 - 75ms/epoch - 3ms/step
# Epoch 156/400
# 27/27 - 0s - loss: 0.4678 - accuracy: 0.7850 - 74ms/epoch - 3ms/step
# Epoch 157/400
# 27/27 - 0s - loss: 0.4613 - accuracy: 0.7664 - 75ms/epoch - 3ms/step
# Epoch 158/400
# 27/27 - 0s - loss: 0.4686 - accuracy: 0.7850 - 74ms/epoch - 3ms/step
# Epoch 159/400
# 27/27 - 0s - loss: 0.3898 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 160/400
# 27/27 - 0s - loss: 0.4458 - accuracy: 0.7664 - 73ms/epoch - 3ms/step
# Epoch 161/400
# 27/27 - 0s - loss: 0.4219 - accuracy: 0.7944 - 72ms/epoch - 3ms/step
# Epoch 162/400
# 27/27 - 0s - loss: 0.4511 - accuracy: 0.8131 - 74ms/epoch - 3ms/step
# Epoch 163/400
# 27/27 - 0s - loss: 0.4481 - accuracy: 0.7383 - 73ms/epoch - 3ms/step
# Epoch 164/400
# 27/27 - 0s - loss: 0.4191 - accuracy: 0.8037 - 74ms/epoch - 3ms/step
# Epoch 165/400
# 27/27 - 0s - loss: 0.4009 - accuracy: 0.7757 - 76ms/epoch - 3ms/step
# Epoch 166/400
# 27/27 - 0s - loss: 0.4314 - accuracy: 0.8131 - 75ms/epoch - 3ms/step
# Epoch 167/400
# 27/27 - 0s - loss: 0.5188 - accuracy: 0.7383 - 75ms/epoch - 3ms/step
# Epoch 168/400
# 27/27 - 0s - loss: 0.4272 - accuracy: 0.7664 - 76ms/epoch - 3ms/step
# Epoch 169/400
# 27/27 - 0s - loss: 0.4423 - accuracy: 0.7664 - 78ms/epoch - 3ms/step
# Epoch 170/400
# 27/27 - 0s - loss: 0.4233 - accuracy: 0.8318 - 74ms/epoch - 3ms/step
# Epoch 171/400
# 27/27 - 0s - loss: 0.4402 - accuracy: 0.7570 - 74ms/epoch - 3ms/step
# Epoch 172/400
# 27/27 - 0s - loss: 0.5002 - accuracy: 0.7477 - 74ms/epoch - 3ms/step
# Epoch 173/400
# 27/27 - 0s - loss: 0.4447 - accuracy: 0.7383 - 78ms/epoch - 3ms/step
# Epoch 174/400
# 27/27 - 0s - loss: 0.4541 - accuracy: 0.7477 - 77ms/epoch - 3ms/step
# Epoch 175/400
# 27/27 - 0s - loss: 0.4347 - accuracy: 0.7944 - 75ms/epoch - 3ms/step
# Epoch 176/400
# 27/27 - 0s - loss: 0.4002 - accuracy: 0.7944 - 77ms/epoch - 3ms/step
# Epoch 177/400
# 27/27 - 0s - loss: 0.3958 - accuracy: 0.7944 - 77ms/epoch - 3ms/step
# Epoch 178/400
# 27/27 - 0s - loss: 0.3568 - accuracy: 0.8131 - 77ms/epoch - 3ms/step
# Epoch 179/400
# 27/27 - 0s - loss: 0.3818 - accuracy: 0.8224 - 76ms/epoch - 3ms/step
# Epoch 180/400
# 27/27 - 0s - loss: 0.4572 - accuracy: 0.7944 - 74ms/epoch - 3ms/step
# Epoch 181/400
# 27/27 - 0s - loss: 0.4754 - accuracy: 0.7570 - 77ms/epoch - 3ms/step
# Epoch 182/400
# 27/27 - 0s - loss: 0.4632 - accuracy: 0.8411 - 74ms/epoch - 3ms/step
# Epoch 183/400
# 27/27 - 0s - loss: 0.4370 - accuracy: 0.7757 - 76ms/epoch - 3ms/step
# Epoch 184/400
# 27/27 - 0s - loss: 0.3523 - accuracy: 0.8224 - 77ms/epoch - 3ms/step
# Epoch 185/400
# 27/27 - 0s - loss: 0.6976 - accuracy: 0.6916 - 76ms/epoch - 3ms/step
# Epoch 186/400
# 27/27 - 0s - loss: 0.5726 - accuracy: 0.6168 - 79ms/epoch - 3ms/step
# Epoch 187/400
# 27/27 - 0s - loss: 0.5283 - accuracy: 0.6822 - 75ms/epoch - 3ms/step
# Epoch 188/400
# 27/27 - 0s - loss: 0.4062 - accuracy: 0.7850 - 74ms/epoch - 3ms/step
# Epoch 189/400
# 27/27 - 0s - loss: 0.3981 - accuracy: 0.8131 - 75ms/epoch - 3ms/step
# Epoch 190/400
# 27/27 - 0s - loss: 0.4689 - accuracy: 0.7383 - 78ms/epoch - 3ms/step
# Epoch 191/400
# 27/27 - 0s - loss: 0.3882 - accuracy: 0.7944 - 76ms/epoch - 3ms/step
# Epoch 192/400
# 27/27 - 0s - loss: 0.4243 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 193/400
# 27/27 - 0s - loss: 0.4157 - accuracy: 0.7850 - 74ms/epoch - 3ms/step
# Epoch 194/400
# 27/27 - 0s - loss: 0.4579 - accuracy: 0.7477 - 77ms/epoch - 3ms/step
# Epoch 195/400
# 27/27 - 0s - loss: 0.4463 - accuracy: 0.7850 - 75ms/epoch - 3ms/step
# Epoch 196/400
# 27/27 - 0s - loss: 0.3840 - accuracy: 0.8505 - 75ms/epoch - 3ms/step
# Epoch 197/400
# 27/27 - 0s - loss: 0.3702 - accuracy: 0.8037 - 74ms/epoch - 3ms/step
# Epoch 198/400
# 27/27 - 0s - loss: 0.3514 - accuracy: 0.8692 - 74ms/epoch - 3ms/step
# Epoch 199/400
# 27/27 - 0s - loss: 0.4487 - accuracy: 0.7944 - 75ms/epoch - 3ms/step
# Epoch 200/400
# 27/27 - 0s - loss: 0.3427 - accuracy: 0.8318 - 75ms/epoch - 3ms/step
# Epoch 201/400
# 27/27 - 0s - loss: 0.4510 - accuracy: 0.7664 - 74ms/epoch - 3ms/step
# Epoch 202/400
# 27/27 - 0s - loss: 0.3418 - accuracy: 0.8224 - 75ms/epoch - 3ms/step
# Epoch 203/400
# 27/27 - 0s - loss: 0.4503 - accuracy: 0.7850 - 74ms/epoch - 3ms/step
# Epoch 204/400
# 27/27 - 0s - loss: 0.4882 - accuracy: 0.7664 - 74ms/epoch - 3ms/step
# Epoch 205/400
# 27/27 - 0s - loss: 0.3914 - accuracy: 0.7850 - 75ms/epoch - 3ms/step
# Epoch 206/400
# 27/27 - 0s - loss: 0.4043 - accuracy: 0.8411 - 73ms/epoch - 3ms/step
# Epoch 207/400
# 27/27 - 0s - loss: 0.3395 - accuracy: 0.8505 - 78ms/epoch - 3ms/step
# Epoch 208/400
# 27/27 - 0s - loss: 0.3597 - accuracy: 0.8785 - 74ms/epoch - 3ms/step
# Epoch 209/400
# 27/27 - 0s - loss: 0.4446 - accuracy: 0.8224 - 76ms/epoch - 3ms/step
# Epoch 210/400
# 27/27 - 0s - loss: 0.4677 - accuracy: 0.7477 - 74ms/epoch - 3ms/step
# Epoch 211/400
# 27/27 - 0s - loss: 0.4623 - accuracy: 0.7664 - 73ms/epoch - 3ms/step
# Epoch 212/400
# 27/27 - 0s - loss: 0.4034 - accuracy: 0.8224 - 75ms/epoch - 3ms/step
# Epoch 213/400
# 27/27 - 0s - loss: 0.3449 - accuracy: 0.8131 - 74ms/epoch - 3ms/step
# Epoch 214/400
# 27/27 - 0s - loss: 0.4284 - accuracy: 0.7944 - 75ms/epoch - 3ms/step
# Epoch 215/400
# 27/27 - 0s - loss: 0.3791 - accuracy: 0.8318 - 72ms/epoch - 3ms/step
# Epoch 216/400
# 27/27 - 0s - loss: 0.3535 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 217/400
# 27/27 - 0s - loss: 0.3706 - accuracy: 0.7944 - 74ms/epoch - 3ms/step
# Epoch 218/400
# 27/27 - 0s - loss: 0.3504 - accuracy: 0.8318 - 76ms/epoch - 3ms/step
# Epoch 219/400
# 27/27 - 0s - loss: 0.3567 - accuracy: 0.8224 - 78ms/epoch - 3ms/step
# Epoch 220/400
# 27/27 - 0s - loss: 0.3555 - accuracy: 0.8411 - 77ms/epoch - 3ms/step
# Epoch 221/400
# 27/27 - 0s - loss: 0.3726 - accuracy: 0.7944 - 76ms/epoch - 3ms/step
# Epoch 222/400
# 27/27 - 0s - loss: 0.3576 - accuracy: 0.8318 - 78ms/epoch - 3ms/step
# Epoch 223/400
# 27/27 - 0s - loss: 0.4009 - accuracy: 0.7850 - 76ms/epoch - 3ms/step
# Epoch 224/400
# 27/27 - 0s - loss: 0.4370 - accuracy: 0.7850 - 77ms/epoch - 3ms/step
# Epoch 225/400
# 27/27 - 0s - loss: 0.3764 - accuracy: 0.8131 - 73ms/epoch - 3ms/step
# Epoch 226/400
# 27/27 - 0s - loss: 0.3327 - accuracy: 0.8411 - 75ms/epoch - 3ms/step
# Epoch 227/400
# 27/27 - 0s - loss: 0.3189 - accuracy: 0.8692 - 73ms/epoch - 3ms/step
# Epoch 228/400
# 27/27 - 0s - loss: 0.3651 - accuracy: 0.8411 - 74ms/epoch - 3ms/step
# Epoch 229/400
# 27/27 - 0s - loss: 0.3422 - accuracy: 0.8598 - 74ms/epoch - 3ms/step
# Epoch 230/400
# 27/27 - 0s - loss: 0.3289 - accuracy: 0.8318 - 75ms/epoch - 3ms/step
# Epoch 231/400
# 27/27 - 0s - loss: 0.3422 - accuracy: 0.8692 - 73ms/epoch - 3ms/step
# Epoch 232/400
# 27/27 - 0s - loss: 0.3207 - accuracy: 0.8505 - 77ms/epoch - 3ms/step
# Epoch 233/400
# 27/27 - 0s - loss: 0.4352 - accuracy: 0.7850 - 72ms/epoch - 3ms/step
# Epoch 234/400
# 27/27 - 0s - loss: 0.3807 - accuracy: 0.8131 - 75ms/epoch - 3ms/step
# Epoch 235/400
# 27/27 - 0s - loss: 0.3602 - accuracy: 0.7757 - 76ms/epoch - 3ms/step
# Epoch 236/400
# 27/27 - 0s - loss: 0.4018 - accuracy: 0.8037 - 74ms/epoch - 3ms/step
# Epoch 237/400
# 27/27 - 0s - loss: 0.3191 - accuracy: 0.8692 - 75ms/epoch - 3ms/step
# Epoch 238/400
# 27/27 - 0s - loss: 0.3194 - accuracy: 0.8318 - 75ms/epoch - 3ms/step
# Epoch 239/400
# 27/27 - 0s - loss: 0.2960 - accuracy: 0.8598 - 73ms/epoch - 3ms/step
# Epoch 240/400
# 27/27 - 0s - loss: 0.2874 - accuracy: 0.8411 - 74ms/epoch - 3ms/step
# Epoch 241/400
# 27/27 - 0s - loss: 0.2975 - accuracy: 0.8879 - 75ms/epoch - 3ms/step
# Epoch 242/400
# 27/27 - 0s - loss: 0.3630 - accuracy: 0.8318 - 73ms/epoch - 3ms/step
# Epoch 243/400
# 27/27 - 0s - loss: 0.2945 - accuracy: 0.8785 - 76ms/epoch - 3ms/step
# Epoch 244/400
# 27/27 - 0s - loss: 0.3629 - accuracy: 0.8318 - 74ms/epoch - 3ms/step
# Epoch 245/400
# 27/27 - 0s - loss: 0.3008 - accuracy: 0.8692 - 73ms/epoch - 3ms/step
# Epoch 246/400
# 27/27 - 0s - loss: 0.2822 - accuracy: 0.9065 - 77ms/epoch - 3ms/step
# Epoch 247/400
# 27/27 - 0s - loss: 0.3048 - accuracy: 0.8972 - 75ms/epoch - 3ms/step
# Epoch 248/400
# 27/27 - 0s - loss: 0.2985 - accuracy: 0.8598 - 74ms/epoch - 3ms/step
# Epoch 249/400
# 27/27 - 0s - loss: 0.3962 - accuracy: 0.8037 - 73ms/epoch - 3ms/step
# Epoch 250/400
# 27/27 - 0s - loss: 0.3253 - accuracy: 0.8692 - 75ms/epoch - 3ms/step
# Epoch 251/400
# 27/27 - 0s - loss: 0.3170 - accuracy: 0.8505 - 74ms/epoch - 3ms/step
# Epoch 252/400
# 27/27 - 0s - loss: 0.3211 - accuracy: 0.8785 - 76ms/epoch - 3ms/step
# Epoch 253/400
# 27/27 - 0s - loss: 0.2325 - accuracy: 0.9159 - 74ms/epoch - 3ms/step
# Epoch 254/400
# 27/27 - 0s - loss: 0.3316 - accuracy: 0.8505 - 72ms/epoch - 3ms/step
# Epoch 255/400
# 27/27 - 0s - loss: 0.3646 - accuracy: 0.8224 - 75ms/epoch - 3ms/step
# Epoch 256/400
# 27/27 - 0s - loss: 0.2747 - accuracy: 0.8598 - 79ms/epoch - 3ms/step
# Epoch 257/400
# 27/27 - 0s - loss: 0.4285 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 258/400
# 27/27 - 0s - loss: 0.3267 - accuracy: 0.8785 - 73ms/epoch - 3ms/step
# Epoch 259/400
# 27/27 - 0s - loss: 0.2375 - accuracy: 0.8879 - 76ms/epoch - 3ms/step
# Epoch 260/400
# 27/27 - 0s - loss: 0.2833 - accuracy: 0.8598 - 75ms/epoch - 3ms/step
# Epoch 261/400
# 27/27 - 0s - loss: 0.3264 - accuracy: 0.8972 - 74ms/epoch - 3ms/step
# Epoch 262/400
# 27/27 - 0s - loss: 0.5235 - accuracy: 0.7664 - 76ms/epoch - 3ms/step
# Epoch 263/400
# 27/27 - 0s - loss: 0.3523 - accuracy: 0.8224 - 77ms/epoch - 3ms/step
# Epoch 264/400
# 27/27 - 0s - loss: 0.3310 - accuracy: 0.8318 - 77ms/epoch - 3ms/step
# Epoch 265/400
# 27/27 - 0s - loss: 0.3329 - accuracy: 0.8505 - 76ms/epoch - 3ms/step
# Epoch 266/400
# 27/27 - 0s - loss: 0.2612 - accuracy: 0.8972 - 76ms/epoch - 3ms/step
# Epoch 267/400
# 27/27 - 0s - loss: 0.2164 - accuracy: 0.9346 - 76ms/epoch - 3ms/step
# Epoch 268/400
# 27/27 - 0s - loss: 0.2097 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 269/400
# 27/27 - 0s - loss: 0.2971 - accuracy: 0.8972 - 77ms/epoch - 3ms/step
# Epoch 270/400
# 27/27 - 0s - loss: 0.2389 - accuracy: 0.9065 - 74ms/epoch - 3ms/step
# Epoch 271/400
# 27/27 - 0s - loss: 0.3059 - accuracy: 0.8411 - 75ms/epoch - 3ms/step
# Epoch 272/400
# 27/27 - 0s - loss: 0.2732 - accuracy: 0.9065 - 77ms/epoch - 3ms/step
# Epoch 273/400
# 27/27 - 0s - loss: 0.2095 - accuracy: 0.8879 - 74ms/epoch - 3ms/step
# Epoch 274/400
# 27/27 - 0s - loss: 0.2961 - accuracy: 0.8505 - 74ms/epoch - 3ms/step
# Epoch 275/400
# 27/27 - 0s - loss: 0.3498 - accuracy: 0.8598 - 76ms/epoch - 3ms/step
# Epoch 276/400
# 27/27 - 0s - loss: 0.3057 - accuracy: 0.8879 - 74ms/epoch - 3ms/step
# Epoch 277/400
# 27/27 - 0s - loss: 0.3560 - accuracy: 0.8224 - 74ms/epoch - 3ms/step
# Epoch 278/400
# 27/27 - 0s - loss: 0.3379 - accuracy: 0.8505 - 74ms/epoch - 3ms/step
# Epoch 279/400
# 27/27 - 0s - loss: 0.2436 - accuracy: 0.8692 - 76ms/epoch - 3ms/step
# Epoch 280/400
# 27/27 - 0s - loss: 0.2779 - accuracy: 0.8598 - 76ms/epoch - 3ms/step
# Epoch 281/400
# 27/27 - 0s - loss: 0.2786 - accuracy: 0.8785 - 73ms/epoch - 3ms/step
# Epoch 282/400
# 27/27 - 0s - loss: 0.2350 - accuracy: 0.8879 - 74ms/epoch - 3ms/step
# Epoch 283/400
# 27/27 - 0s - loss: 0.2413 - accuracy: 0.8879 - 74ms/epoch - 3ms/step
# Epoch 284/400
# 27/27 - 0s - loss: 0.2219 - accuracy: 0.9439 - 74ms/epoch - 3ms/step
# Epoch 285/400
# 27/27 - 0s - loss: 0.1784 - accuracy: 0.9439 - 76ms/epoch - 3ms/step
# Epoch 286/400
# 27/27 - 0s - loss: 0.2164 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 287/400
# 27/27 - 0s - loss: 0.2831 - accuracy: 0.8785 - 73ms/epoch - 3ms/step
# Epoch 288/400
# 27/27 - 0s - loss: 0.2790 - accuracy: 0.8972 - 78ms/epoch - 3ms/step
# Epoch 289/400
# 27/27 - 0s - loss: 0.3920 - accuracy: 0.8972 - 74ms/epoch - 3ms/step
# Epoch 290/400
# 27/27 - 0s - loss: 0.1423 - accuracy: 0.9720 - 74ms/epoch - 3ms/step
# Epoch 291/400
# 27/27 - 0s - loss: 0.3064 - accuracy: 0.8785 - 73ms/epoch - 3ms/step
# Epoch 292/400
# 27/27 - 0s - loss: 0.9184 - accuracy: 0.6075 - 74ms/epoch - 3ms/step
# Epoch 293/400
# 27/27 - 0s - loss: 0.7051 - accuracy: 0.5794 - 73ms/epoch - 3ms/step
# Epoch 294/400
# 27/27 - 0s - loss: 0.5389 - accuracy: 0.7290 - 72ms/epoch - 3ms/step
# Epoch 295/400
# 27/27 - 0s - loss: 0.4900 - accuracy: 0.7290 - 73ms/epoch - 3ms/step
# Epoch 296/400
# 27/27 - 0s - loss: 0.4111 - accuracy: 0.8318 - 74ms/epoch - 3ms/step
# Epoch 297/400
# 27/27 - 0s - loss: 0.3298 - accuracy: 0.8318 - 73ms/epoch - 3ms/step
# Epoch 298/400
# 27/27 - 0s - loss: 0.2290 - accuracy: 0.9159 - 77ms/epoch - 3ms/step
# Epoch 299/400
# 27/27 - 0s - loss: 0.2451 - accuracy: 0.8972 - 75ms/epoch - 3ms/step
# Epoch 300/400
# 27/27 - 0s - loss: 0.3158 - accuracy: 0.8505 - 75ms/epoch - 3ms/step
# Epoch 301/400
# 27/27 - 0s - loss: 0.3806 - accuracy: 0.8224 - 74ms/epoch - 3ms/step
# Epoch 302/400
# 27/27 - 0s - loss: 0.3718 - accuracy: 0.8505 - 75ms/epoch - 3ms/step
# Epoch 303/400
# 27/27 - 0s - loss: 0.2588 - accuracy: 0.8879 - 75ms/epoch - 3ms/step
# Epoch 304/400
# 27/27 - 0s - loss: 0.2287 - accuracy: 0.8972 - 76ms/epoch - 3ms/step
# Epoch 305/400
# 27/27 - 0s - loss: 0.1765 - accuracy: 0.9346 - 73ms/epoch - 3ms/step
# Epoch 306/400
# 27/27 - 0s - loss: 0.2023 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 307/400
# 27/27 - 0s - loss: 0.1988 - accuracy: 0.9252 - 73ms/epoch - 3ms/step
# Epoch 308/400
# 27/27 - 0s - loss: 0.1375 - accuracy: 0.9439 - 76ms/epoch - 3ms/step
# Epoch 309/400
# 27/27 - 0s - loss: 0.1673 - accuracy: 0.9533 - 72ms/epoch - 3ms/step
# Epoch 310/400
# 27/27 - 0s - loss: 0.1942 - accuracy: 0.9439 - 75ms/epoch - 3ms/step
# Epoch 311/400
# 27/27 - 0s - loss: 0.0954 - accuracy: 0.9720 - 75ms/epoch - 3ms/step
# Epoch 312/400
# 27/27 - 0s - loss: 0.2117 - accuracy: 0.9252 - 74ms/epoch - 3ms/step
# Epoch 313/400
# 27/27 - 0s - loss: 0.3474 - accuracy: 0.8505 - 74ms/epoch - 3ms/step
# Epoch 314/400
# 27/27 - 0s - loss: 0.2758 - accuracy: 0.9065 - 73ms/epoch - 3ms/step
# Epoch 315/400
# 27/27 - 0s - loss: 0.2066 - accuracy: 0.9065 - 73ms/epoch - 3ms/step
# Epoch 316/400
# 27/27 - 0s - loss: 0.2077 - accuracy: 0.9065 - 73ms/epoch - 3ms/step
# Epoch 317/400
# 27/27 - 0s - loss: 0.3734 - accuracy: 0.8224 - 73ms/epoch - 3ms/step
# Epoch 318/400
# 27/27 - 0s - loss: 0.4508 - accuracy: 0.7944 - 74ms/epoch - 3ms/step
# Epoch 319/400
# 27/27 - 0s - loss: 0.2530 - accuracy: 0.9065 - 76ms/epoch - 3ms/step
# Epoch 320/400
# 27/27 - 0s - loss: 0.2198 - accuracy: 0.9252 - 75ms/epoch - 3ms/step
# Epoch 321/400
# 27/27 - 0s - loss: 0.2742 - accuracy: 0.9065 - 74ms/epoch - 3ms/step
# Epoch 322/400
# 27/27 - 0s - loss: 0.1579 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 323/400
# 27/27 - 0s - loss: 0.1410 - accuracy: 0.9533 - 75ms/epoch - 3ms/step
# Epoch 324/400
# 27/27 - 0s - loss: 0.4208 - accuracy: 0.8224 - 74ms/epoch - 3ms/step
# Epoch 325/400
# 27/27 - 0s - loss: 0.3242 - accuracy: 0.9159 - 75ms/epoch - 3ms/step
# Epoch 326/400
# 27/27 - 0s - loss: 0.1793 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 327/400
# 27/27 - 0s - loss: 0.1578 - accuracy: 0.9720 - 73ms/epoch - 3ms/step
# Epoch 328/400
# 27/27 - 0s - loss: 0.1618 - accuracy: 0.9439 - 73ms/epoch - 3ms/step
# Epoch 329/400
# 27/27 - 0s - loss: 0.2163 - accuracy: 0.9252 - 72ms/epoch - 3ms/step
# Epoch 330/400
# 27/27 - 0s - loss: 0.2920 - accuracy: 0.8785 - 73ms/epoch - 3ms/step
# Epoch 331/400
# 27/27 - 0s - loss: 0.1502 - accuracy: 0.9439 - 73ms/epoch - 3ms/step
# Epoch 332/400
# 27/27 - 0s - loss: 0.7611 - accuracy: 0.8131 - 75ms/epoch - 3ms/step
# Epoch 333/400
# 27/27 - 0s - loss: 0.4996 - accuracy: 0.7477 - 73ms/epoch - 3ms/step
# Epoch 334/400
# 27/27 - 0s - loss: 0.2278 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 335/400
# 27/27 - 0s - loss: 0.1800 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 336/400
# 27/27 - 0s - loss: 0.1767 - accuracy: 0.9533 - 76ms/epoch - 3ms/step
# Epoch 337/400
# 27/27 - 0s - loss: 0.2052 - accuracy: 0.9159 - 77ms/epoch - 3ms/step
# Epoch 338/400
# 27/27 - 0s - loss: 0.8590 - accuracy: 0.6075 - 79ms/epoch - 3ms/step
# Epoch 339/400
# 27/27 - 0s - loss: 0.3576 - accuracy: 0.8598 - 77ms/epoch - 3ms/step
# Epoch 340/400
# 27/27 - 0s - loss: 0.2205 - accuracy: 0.9439 - 77ms/epoch - 3ms/step
# Epoch 341/400
# 27/27 - 0s - loss: 0.2074 - accuracy: 0.9159 - 76ms/epoch - 3ms/step
# Epoch 342/400
# 27/27 - 0s - loss: 0.3019 - accuracy: 0.8879 - 77ms/epoch - 3ms/step
# Epoch 343/400
# 27/27 - 0s - loss: 0.2661 - accuracy: 0.8785 - 77ms/epoch - 3ms/step
# Epoch 344/400
# 27/27 - 0s - loss: 0.1450 - accuracy: 0.9720 - 74ms/epoch - 3ms/step
# Epoch 345/400
# 27/27 - 0s - loss: 0.1191 - accuracy: 0.9626 - 74ms/epoch - 3ms/step
# Epoch 346/400
# 27/27 - 0s - loss: 0.1665 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 347/400
# 27/27 - 0s - loss: 0.1608 - accuracy: 0.9065 - 74ms/epoch - 3ms/step
# Epoch 348/400
# 27/27 - 0s - loss: 0.1910 - accuracy: 0.9252 - 73ms/epoch - 3ms/step
# Epoch 349/400
# 27/27 - 0s - loss: 0.2180 - accuracy: 0.9252 - 76ms/epoch - 3ms/step
# Epoch 350/400
# 27/27 - 0s - loss: 0.2067 - accuracy: 0.9439 - 74ms/epoch - 3ms/step
# Epoch 351/400
# 27/27 - 0s - loss: 0.3761 - accuracy: 0.8037 - 75ms/epoch - 3ms/step
# Epoch 352/400
# 27/27 - 0s - loss: 0.1841 - accuracy: 0.9159 - 75ms/epoch - 3ms/step
# Epoch 353/400
# 27/27 - 0s - loss: 0.0911 - accuracy: 0.9720 - 74ms/epoch - 3ms/step
# Epoch 354/400
# 27/27 - 0s - loss: 0.7678 - accuracy: 0.7850 - 75ms/epoch - 3ms/step
# Epoch 355/400
# 27/27 - 0s - loss: 0.6738 - accuracy: 0.6729 - 73ms/epoch - 3ms/step
# Epoch 356/400
# 27/27 - 0s - loss: 0.4937 - accuracy: 0.7477 - 76ms/epoch - 3ms/step
# Epoch 357/400
# 27/27 - 0s - loss: 0.2687 - accuracy: 0.8972 - 74ms/epoch - 3ms/step
# Epoch 358/400
# 27/27 - 0s - loss: 0.1544 - accuracy: 0.9533 - 75ms/epoch - 3ms/step
# Epoch 359/400
# 27/27 - 0s - loss: 0.1214 - accuracy: 0.9626 - 73ms/epoch - 3ms/step
# Epoch 360/400
# 27/27 - 0s - loss: 0.1229 - accuracy: 0.9813 - 77ms/epoch - 3ms/step
# Epoch 361/400
# 27/27 - 0s - loss: 0.1700 - accuracy: 0.9439 - 75ms/epoch - 3ms/step
# Epoch 362/400
# 27/27 - 0s - loss: 0.3490 - accuracy: 0.8318 - 72ms/epoch - 3ms/step
# Epoch 363/400
# 27/27 - 0s - loss: 0.2275 - accuracy: 0.9065 - 73ms/epoch - 3ms/step
# Epoch 364/400
# 27/27 - 0s - loss: 0.2416 - accuracy: 0.9252 - 74ms/epoch - 3ms/step
# Epoch 365/400
# 27/27 - 0s - loss: 0.2163 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 366/400
# 27/27 - 0s - loss: 0.1579 - accuracy: 0.9626 - 76ms/epoch - 3ms/step
# Epoch 367/400
# 27/27 - 0s - loss: 0.1708 - accuracy: 0.9533 - 72ms/epoch - 3ms/step
# Epoch 368/400
# 27/27 - 0s - loss: 0.1702 - accuracy: 0.8972 - 74ms/epoch - 3ms/step
# Epoch 369/400
# 27/27 - 0s - loss: 0.1710 - accuracy: 0.9346 - 74ms/epoch - 3ms/step
# Epoch 370/400
# 27/27 - 0s - loss: 0.1652 - accuracy: 0.9159 - 73ms/epoch - 3ms/step
# Epoch 371/400
# 27/27 - 0s - loss: 0.4168 - accuracy: 0.8224 - 73ms/epoch - 3ms/step
# Epoch 372/400
# 27/27 - 0s - loss: 0.3382 - accuracy: 0.8411 - 75ms/epoch - 3ms/step
# Epoch 373/400
# 27/27 - 0s - loss: 0.2237 - accuracy: 0.9159 - 71ms/epoch - 3ms/step
# Epoch 374/400
# 27/27 - 0s - loss: 0.1534 - accuracy: 0.9346 - 76ms/epoch - 3ms/step
# Epoch 375/400
# 27/27 - 0s - loss: 0.1002 - accuracy: 0.9720 - 76ms/epoch - 3ms/step
# Epoch 376/400
# 27/27 - 0s - loss: 0.2761 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 377/400
# 27/27 - 0s - loss: 0.3188 - accuracy: 0.8972 - 75ms/epoch - 3ms/step
# Epoch 378/400
# 27/27 - 0s - loss: 0.4878 - accuracy: 0.7757 - 74ms/epoch - 3ms/step
# Epoch 379/400
# 27/27 - 0s - loss: 0.1889 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 380/400
# 27/27 - 0s - loss: 0.1586 - accuracy: 0.9533 - 74ms/epoch - 3ms/step
# Epoch 381/400
# 27/27 - 0s - loss: 0.2218 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 382/400
# 27/27 - 0s - loss: 0.2706 - accuracy: 0.8879 - 74ms/epoch - 3ms/step
# Epoch 383/400
# 27/27 - 0s - loss: 0.1848 - accuracy: 0.9346 - 75ms/epoch - 3ms/step
# Epoch 384/400
# 27/27 - 0s - loss: 0.0758 - accuracy: 0.9813 - 74ms/epoch - 3ms/step
# Epoch 385/400
# 27/27 - 0s - loss: 0.2114 - accuracy: 0.9159 - 75ms/epoch - 3ms/step
# Epoch 386/400
# 27/27 - 0s - loss: 0.1179 - accuracy: 0.9626 - 73ms/epoch - 3ms/step
# Epoch 387/400
# 27/27 - 0s - loss: 0.1344 - accuracy: 0.9626 - 74ms/epoch - 3ms/step
# Epoch 388/400
# 27/27 - 0s - loss: 0.1210 - accuracy: 0.9626 - 72ms/epoch - 3ms/step
# Epoch 389/400
# 27/27 - 0s - loss: 0.0752 - accuracy: 0.9813 - 71ms/epoch - 3ms/step
# Epoch 390/400
# 27/27 - 0s - loss: 0.1293 - accuracy: 0.9626 - 75ms/epoch - 3ms/step
# Epoch 391/400
# 27/27 - 0s - loss: 0.2767 - accuracy: 0.8785 - 75ms/epoch - 3ms/step
# Epoch 392/400
# 27/27 - 0s - loss: 0.3053 - accuracy: 0.8972 - 74ms/epoch - 3ms/step
# Epoch 393/400
# 27/27 - 0s - loss: 0.2149 - accuracy: 0.9252 - 75ms/epoch - 3ms/step
# Epoch 394/400
# 27/27 - 0s - loss: 0.1453 - accuracy: 0.9439 - 72ms/epoch - 3ms/step
# Epoch 395/400
# 27/27 - 0s - loss: 0.0963 - accuracy: 0.9533 - 75ms/epoch - 3ms/step
# Epoch 396/400
# 27/27 - 0s - loss: 0.0822 - accuracy: 0.9626 - 74ms/epoch - 3ms/step
# Epoch 397/400
# 27/27 - 0s - loss: 0.1593 - accuracy: 0.9252 - 76ms/epoch - 3ms/step
# Epoch 398/400
# 27/27 - 0s - loss: 0.1248 - accuracy: 0.9439 - 77ms/epoch - 3ms/step
# Epoch 399/400
# 27/27 - 0s - loss: 0.2712 - accuracy: 0.9252 - 75ms/epoch - 3ms/step
# Epoch 400/400
# 27/27 - 0s - loss: 0.1283 - accuracy: 0.9439 - 74ms/epoch - 3ms/step

# %%
y_pred = model.predict(dataset)
# print(y_pred, targets)
matrix = sklearn.metrics.confusion_matrix(targets, y_pred.round())
print(matrix)
# Out:
# [[53  0]
#  [ 2 52]]

# %%
from keras.callbacks import EarlyStopping

def load_data():
    normal_data = get_data(NORMAL_INPUT_DATA_DIR)
    fault_data = get_data(FAULT_INPUT_DATA_DIR)
    data = np.concatenate((normal_data, fault_data))
    labels = np.concatenate((np.zeros(len(normal_data)), np.ones(len(fault_data))))
    return data, labels

def create_model():
    model = Sequential()
    model.add(LSTM(100, input_shape=(n_timesteps,n_features)))
    model.add(Dropout(0.5))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test):
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.1) 
    model.fit(data_train, labels_train,validation_data=(data_test, labels_test), epochs=100, batch_size=8, verbose=0,callbacks=[PlotLossesKeras(), es],)

n_splits = 5
data, labels = load_data()
skf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)

for i,(train, test) in enumerate(skf.split(data, labels)):
    print("Running Fold", i+1, "/", n_folds)
    model = None # Clearing the NN.
    model = create_model()
    train_and_evaluate_model(model, data[train], labels[train], data[test], labels[test])
    y_pred = model.predict(dataset)
    matrix = sklearn.metrics.confusion_matrix(targets[test], y_pred[test].round())
    # Plot Confusion matrix
    sns.heatmap(matrix, square=True, annot=True, cbar=False, cmap=plt.cm.Blues, fmt='.0f')
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values');
    plt.show();
# Out:
# An exception occurred
# Running Fold 1 / 5
# [[11  0]
#  [10  1]]
# Running Fold 2 / 5
# [[9 2]
#  [2 9]]
# Running Fold 3 / 5
# [[ 6  5]
#  [ 0 10]]
# Running Fold 4 / 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_62752/1417229413.py in <module>
#      26     model = None # Clearing the NN.
#      27     model = create_model()
# ---> 28     train_and_evaluate_model(model, data[train], labels[train], data[test], labels[test])
#      29     y_pred = model.predict(dataset)
#      30     matrix = sklearn.metrics.confusion_matrix(targets[test], y_pred[test].round())
#
# ~\AppData\Local\Temp/ipykernel_62752/1417229413.py in train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test)
#      16
#      17 def train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test):
# ---> 18     model.fit(data_train, labels_train,validation_data=(data_test, labels_test), epochs=100, batch_size=8, verbose=0)
#      19
#      20 n_splits = 5
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1418                 model=self,
#    1419                 steps_per_execution=self._steps_per_execution)
# -> 1420           val_logs = self.evaluate(
#    1421               x=val_x,
#    1422               y=val_y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1708       self._test_counter.assign(0)
#    1709       callbacks.on_test_begin()
# -> 1710       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1711         self.reset_metrics()
#    1712         with data_handler.catch_stop_iteration():
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3312   if tld.is_eager:
#    3313     try:
# -> 3314       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3315         _ctx, "MakeIterator", name, dataset, iterator)
#    3316       return _result
#
# KeyboardInterrupt:
