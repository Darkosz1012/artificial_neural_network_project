# %%
import os
import glob
import pickle
from datetime import datetime

import numpy as np
import pandas as pd
import sklearn
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU
from keras.metrics import AUC,Precision,Recall
from sklearn.model_selection import StratifiedKFold
from tensorflow import keras

# %%
NORMAL_INPUT_DATA_DIR = "./split_data/normal/"
FAULT_INPUT_DATA_DIR = "./split_data/fault/"
TRAIN_RESULTS_DIR = './train_results'

# %%
files = glob.glob('./models/*')
for f in files:
    print(f)
    os.remove(f)
# Out:
# ./models\new.hdf5
# ./models\vl0.041945va0.989097m0s2f2.hdf5
# ./models\vl0.053769va0.984424m0s2f1.hdf5

# %%
def get_data(input_dir, series_size=31):
    data = []
    for (dirpath, dirnames, filenames) in os.walk(input_dir):
        for filename in filenames:
            try:
                path = input_dir+"/" + filename
                frame = pd.read_csv(path, header=None)
                if frame.to_numpy().shape == (31,10):
                    data.append(frame.to_numpy().tolist())
            except Exception as exp:
                print(filename)
                print(exp)

    split_data = []
    for i in range(0,len(data)):
        for j in range(0,len(data[i])-series_size+1):
            split_data.append(data[i][j:j+series_size])
    return np.array(split_data)[:,:,1:10]

# %%
def load_data(series_size):
    normal_data = get_data(NORMAL_INPUT_DATA_DIR,series_size)
    fault_data = get_data(FAULT_INPUT_DATA_DIR,series_size)
    data = np.concatenate((normal_data, fault_data))
    labels = np.concatenate((np.zeros(len(normal_data)), np.ones(len(fault_data))))
    return data, labels

# %%
def create_model(data, architecture=0, n_timesteps=31, n_features=9,n_outputs=1):
    tf.keras.backend.clear_session()
    model = None
    input_shape = (n_timesteps,n_features)
    layer = tf.keras.layers.Normalization(axis=2,input_shape=input_shape)
    layer.adapt(data)
    model = Sequential()
    model.add(layer)
    
    if architecture == 0:
        model.add(LSTM(100, kernel_initializer='random_normal',bias_initializer='zeros'))
        model.add(Dropout(0.5))
        model.add(Dense(100, activation='relu'))
        
    if architecture == 1:
        model.add(LSTM(units = 50, return_sequences = True, kernel_initializer='random_normal',bias_initializer='zeros'))
        model.add(Dropout(0.4))

        model.add(LSTM(units = 50, return_sequences = True))
        model.add(Dropout(0.4))

        model.add(LSTM(units = 50, return_sequences = True))
        model.add(Dropout(0.4))

        model.add(LSTM(units = 50))
        model.add(Dropout(0.4))
        
    if architecture == 2:
        model.add(GRU(100, kernel_initializer='random_normal',bias_initializer='zeros'))
        model.add(Dropout(0.5))
        model.add(Dense(100, activation='relu'))
        
    if architecture == 3:
        model.add(GRU(units = 50, return_sequences = True, kernel_initializer='random_normal',bias_initializer='zeros'))
        model.add(Dropout(0.4))

        model.add(GRU(units = 50, return_sequences = True))
        model.add(Dropout(0.4))

        model.add(GRU(units = 50, return_sequences = True))
        model.add(Dropout(0.4))

        model.add(GRU(units = 50))
        model.add(Dropout(0.4))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    opt = keras.optimizers.Adam(learning_rate=0.0005)
    
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy',AUC(),Precision(),Recall()])
    return model

# %%
def train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test):
    checkpoint_filepath = './models/new.hdf5'
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor='val_loss',
        mode='min',
        save_best_only=True)
    return model.fit(data_train, labels_train,
                     validation_data=(data_test, labels_test), 
                     epochs=30, batch_size=32, verbose=0,
                     callbacks=[model_checkpoint_callback],)

# %%
title = []
avg = []
desc = []
history = []
models = []
conf_mat =[]
params = []

n_splits = 5
number_of_models = [
    0,
    1,
    2,
    3,
]
series_sizes = [
    2,
    5, 
    10,
    31,
]
cross_validation = True

for num_model in number_of_models:
    for series_size in series_sizes:
        
        title.append("Model number: "+str(num_model)+"   Series size: "+ str(series_size))
        params.append([num_model,series_size])
        print(title[-1])
        desc.append([])
        history.append([])
        models.append([])
        conf_mat.append([])
        

        avg.append([0.0,0.0,0.0])
        
        data, labels = load_data(series_size)
        skf = StratifiedKFold(n_splits=n_splits, random_state=None, shuffle=True)
        for i,(train, test) in enumerate(skf.split(data, labels)):
            if cross_validation == True or i == 0:
                start_time = datetime.now()
                
                models[-1].append(create_model(data,num_model, series_size))
                
                history[-1].append(train_and_evaluate_model(models[-1][-1], data[train], labels[train], data[test], labels[test]).history)
                end_time = datetime.now()
                
                models[-1][-1] = keras.models.load_model('./models/new.hdf5')
                
                y_pred = models[-1][-1].predict(data)
                conf_mat[-1].append(sklearn.metrics.confusion_matrix(labels[test], y_pred[test].round()))
                
                his = history[-1][-1]
                val_loss = np.min(his['val_loss'])
                val_acc_when_min_loss = his['val_accuracy'][np.argmin(his['val_loss'])]
                val_acc = np.max(his['val_accuracy'])
                avg[-1][0]+=val_loss
                avg[-1][1]+=val_acc_when_min_loss
                avg[-1][2]+=val_acc
                desc[-1].append("m"+str(num_model)+"s"+str(series_size)+"f"+str(i+1)
                           + "   min_val_loss = {0:.6f}".format(val_loss) + 
                                "   val_acc_when_min_loss = {0:.6f}".format(val_acc_when_min_loss) +
                                "   max_val_acc = {0:.6f}".format(val_acc))
                print(desc[-1][-1])
                print('Duration: {}'.format(end_time - start_time))

                os.rename("./models/new.hdf5", "./models/vl{0:.6f}".format(val_loss)
                          +"va{0:.6f}".format(val_acc_when_min_loss)
                          +"m"+str(num_model)+"s"+str(series_size)+"f"+str(i+1)+".hdf5")
        if cross_validation == True:
            avg[-1][0] /= n_splits
            avg[-1][1] /= n_splits
            avg[-1][2] /= n_splits
        print("Average min val loss: ", avg[-1][0], "  Average val accuracy when min loss: ",avg[-1][1],"  Average max val accuracy: ",avg[-1][1],"\n\n")
# Out:
# Model number: 0   Series size: 2
# m0s2f1   min_val_loss = 0.048448   val_acc_when_min_loss = 0.985981   max_val_acc = 0.987539
# Duration: 0:00:09.578989
# m0s2f2   min_val_loss = 0.072309   val_acc_when_min_loss = 0.978193   max_val_acc = 0.979751
# Duration: 0:00:09.294176
# m0s2f3   min_val_loss = 0.063943   val_acc_when_min_loss = 0.979751   max_val_acc = 0.981308
# Duration: 0:00:11.351029
# m0s2f4   min_val_loss = 0.053028   val_acc_when_min_loss = 0.982866   max_val_acc = 0.982866
# Duration: 0:00:09.493590
# m0s2f5   min_val_loss = 0.062140   val_acc_when_min_loss = 0.981308   max_val_acc = 0.982866
# Duration: 0:00:09.595014
# Average min val loss:  0.059973782300949095   Average val accuracy when min loss:  0.981619930267334   Average max val accuracy:  0.981619930267334
#
#
# Model number: 0   Series size: 5
# m0s5f1   min_val_loss = 0.023125   val_acc_when_min_loss = 0.994810   max_val_acc = 0.994810
# Duration: 0:00:09.008574
# m0s5f2   min_val_loss = 0.005486   val_acc_when_min_loss = 0.996540   max_val_acc = 0.996540
# Duration: 0:00:09.010953
# m0s5f3   min_val_loss = 0.010370   val_acc_when_min_loss = 0.994810   max_val_acc = 0.994810
# Duration: 0:00:09.043267
# m0s5f4   min_val_loss = 0.014189   val_acc_when_min_loss = 0.993080   max_val_acc = 0.994810
# Duration: 0:00:08.842908
# m0s5f5   min_val_loss = 0.009816   val_acc_when_min_loss = 0.996534   max_val_acc = 0.996534
# Duration: 0:00:09.009948
# Average min val loss:  0.012597204558551312   Average val accuracy when min loss:  0.9951545119285583   Average max val accuracy:  0.9951545119285583
#
#
# Model number: 0   Series size: 10
# m0s10f1   min_val_loss = 0.000559   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.891425
# m0s10f2   min_val_loss = 0.010573   val_acc_when_min_loss = 0.997877   max_val_acc = 0.997877
# Duration: 0:00:07.948120
# m0s10f3   min_val_loss = 0.000012   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.828366
# m0s10f4   min_val_loss = 0.000116   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:08.224245
# m0s10f5   min_val_loss = 0.000055   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.820621
# Average min val loss:  0.002262931341283547   Average val accuracy when min loss:  0.9995753765106201   Average max val accuracy:  0.9995753765106201
#
#
# Model number: 0   Series size: 31
# m0s31f1   min_val_loss = 0.000999   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:02.891710
# m0s31f2   min_val_loss = 0.115236   val_acc_when_min_loss = 0.954545   max_val_acc = 0.954545
# Duration: 0:00:03.004735
# m0s31f3   min_val_loss = 0.004516   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:02.941234
# m0s31f4   min_val_loss = 0.019446   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:03.013140
# m0s31f5   min_val_loss = 0.104917   val_acc_when_min_loss = 0.952381   max_val_acc = 1.000000
# Duration: 0:00:02.759616
# Average min val loss:  0.04902264007832855   Average val accuracy when min loss:  0.9813852787017823   Average max val accuracy:  0.9813852787017823
#
#
# Model number: 1   Series size: 2
# m1s2f1   min_val_loss = 0.034592   val_acc_when_min_loss = 0.993769   max_val_acc = 0.993769
# Duration: 0:00:18.245942
# m1s2f2   min_val_loss = 0.085237   val_acc_when_min_loss = 0.971963   max_val_acc = 0.971963
# Duration: 0:00:17.926136
# m1s2f3   min_val_loss = 0.058687   val_acc_when_min_loss = 0.979751   max_val_acc = 0.981308
# Duration: 0:00:18.078303
# m1s2f4   min_val_loss = 0.057898   val_acc_when_min_loss = 0.979751   max_val_acc = 0.982866
# Duration: 0:00:18.166627
# m1s2f5   min_val_loss = 0.083601   val_acc_when_min_loss = 0.973520   max_val_acc = 0.975078
# Duration: 0:00:18.078607
# Average min val loss:  0.06400295495986938   Average val accuracy when min loss:  0.9797507762908936   Average max val accuracy:  0.9797507762908936
#
#
# Model number: 1   Series size: 5
# m1s5f1   min_val_loss = 0.029109   val_acc_when_min_loss = 0.994810   max_val_acc = 0.994810
# Duration: 0:00:17.597887
# m1s5f2   min_val_loss = 0.012256   val_acc_when_min_loss = 0.994810   max_val_acc = 0.996540
# Duration: 0:00:17.470645
# m1s5f3   min_val_loss = 0.030221   val_acc_when_min_loss = 0.989619   max_val_acc = 0.989619
# Duration: 0:00:17.217319
# m1s5f4   min_val_loss = 0.012469   val_acc_when_min_loss = 0.993080   max_val_acc = 0.994810
# Duration: 0:00:18.098490
# m1s5f5   min_val_loss = 0.006407   val_acc_when_min_loss = 0.998267   max_val_acc = 0.998267
# Duration: 0:00:17.601122
# Average min val loss:  0.018092317786067725   Average val accuracy when min loss:  0.9941170454025269   Average max val accuracy:  0.9941170454025269
#
#
# Model number: 1   Series size: 10
# m1s10f1   min_val_loss = 0.000042   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:16.411103
# m1s10f2   min_val_loss = 0.000191   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:16.008450
# m1s10f3   min_val_loss = 0.000048   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:16.048317
# m1s10f4   min_val_loss = 0.000420   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:16.656284
# m1s10f5   min_val_loss = 0.004037   val_acc_when_min_loss = 0.997872   max_val_acc = 0.997872
# Duration: 0:00:16.689173
# Average min val loss:  0.0009475353595917113   Average val accuracy when min loss:  0.9995744705200196   Average max val accuracy:  0.9995744705200196
#
#
# Model number: 1   Series size: 31
# m1s31f1   min_val_loss = 0.007968   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.686977
# m1s31f2   min_val_loss = 0.016032   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.978999
# m1s31f3   min_val_loss = 0.041977   val_acc_when_min_loss = 0.952381   max_val_acc = 0.952381
# Duration: 0:00:05.755747
# m1s31f4   min_val_loss = 0.005273   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.564386
# m1s31f5   min_val_loss = 0.006228   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:06.089631
# Average min val loss:  0.015495406836271286   Average val accuracy when min loss:  0.9904761910438538   Average max val accuracy:  0.9904761910438538
#
#
# Model number: 2   Series size: 2
# m2s2f1   min_val_loss = 0.052710   val_acc_when_min_loss = 0.984424   max_val_acc = 0.985981
# Duration: 0:00:09.241088
# m2s2f2   min_val_loss = 0.067104   val_acc_when_min_loss = 0.975078   max_val_acc = 0.976636
# Duration: 0:00:09.572978
# m2s2f3   min_val_loss = 0.074144   val_acc_when_min_loss = 0.975078   max_val_acc = 0.979751
# Duration: 0:00:09.149395
# m2s2f4   min_val_loss = 0.045311   val_acc_when_min_loss = 0.989097   max_val_acc = 0.990654
# Duration: 0:00:09.195241
# m2s2f5   min_val_loss = 0.064482   val_acc_when_min_loss = 0.981308   max_val_acc = 0.981308
# Duration: 0:00:09.257034
# Average min val loss:  0.060750371962785724   Average val accuracy when min loss:  0.9809968829154968   Average max val accuracy:  0.9809968829154968
#
#
# Model number: 2   Series size: 5
# m2s5f1   min_val_loss = 0.002516   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:09.127468
# m2s5f2   min_val_loss = 0.003042   val_acc_when_min_loss = 0.998270   max_val_acc = 0.998270
# Duration: 0:00:08.644086
# m2s5f3   min_val_loss = 0.022348   val_acc_when_min_loss = 0.993080   max_val_acc = 0.993080
# Duration: 0:00:08.960028
# m2s5f4   min_val_loss = 0.003948   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:08.844415
# m2s5f5   min_val_loss = 0.027415   val_acc_when_min_loss = 0.994801   max_val_acc = 0.994801
# Duration: 0:00:08.804548
# Average min val loss:  0.011853828420862555   Average val accuracy when min loss:  0.9972300410270691   Average max val accuracy:  0.9972300410270691
#
#
# Model number: 2   Series size: 10
# m2s10f1   min_val_loss = 0.000124   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:08.176649
# m2s10f2   min_val_loss = 0.000556   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.637452
# m2s10f3   min_val_loss = 0.000401   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.624495
# m2s10f4   min_val_loss = 0.000317   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:07.532803
# m2s10f5   min_val_loss = 0.005740   val_acc_when_min_loss = 0.997872   max_val_acc = 0.997872
# Duration: 0:00:07.581639
# Average min val loss:  0.0014277545706136152   Average val accuracy when min loss:  0.9995744705200196   Average max val accuracy:  0.9995744705200196
#
#
# Model number: 2   Series size: 31
# m2s31f1   min_val_loss = 0.002103   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:02.781695
# m2s31f2   min_val_loss = 0.000468   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:02.838503
# m2s31f3   min_val_loss = 0.051157   val_acc_when_min_loss = 0.952381   max_val_acc = 1.000000
# Duration: 0:00:02.650136
# m2s31f4   min_val_loss = 0.005239   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:02.790665
# m2s31f5   min_val_loss = 0.007441   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:03.309929
# Average min val loss:  0.013281805632868782   Average val accuracy when min loss:  0.9904761910438538   Average max val accuracy:  0.9904761910438538
#
#
# Model number: 3   Series size: 2
# m3s2f1   min_val_loss = 0.079824   val_acc_when_min_loss = 0.981308   max_val_acc = 0.981308
# Duration: 0:00:16.852627
# m3s2f2   min_val_loss = 0.067746   val_acc_when_min_loss = 0.979751   max_val_acc = 0.979751
# Duration: 0:00:17.229366
# m3s2f3   min_val_loss = 0.050633   val_acc_when_min_loss = 0.984424   max_val_acc = 0.989097
# Duration: 0:00:16.911430
# m3s2f4   min_val_loss = 0.072994   val_acc_when_min_loss = 0.973520   max_val_acc = 0.975078
# Duration: 0:00:17.413749
# m3s2f5   min_val_loss = 0.074740   val_acc_when_min_loss = 0.967290   max_val_acc = 0.970405
# Duration: 0:00:16.935473
# Average min val loss:  0.0691871739923954   Average val accuracy when min loss:  0.9772585749626159   Average max val accuracy:  0.9772585749626159
#
#
# Model number: 3   Series size: 5
# m3s5f1   min_val_loss = 0.007208   val_acc_when_min_loss = 0.998270   max_val_acc = 0.998270
# Duration: 0:00:16.995895
# m3s5f2   min_val_loss = 0.007685   val_acc_when_min_loss = 0.996540   max_val_acc = 0.996540
# Duration: 0:00:16.465942
# m3s5f3   min_val_loss = 0.044736   val_acc_when_min_loss = 0.987889   max_val_acc = 0.989619
# Duration: 0:00:16.910375
# m3s5f4   min_val_loss = 0.017239   val_acc_when_min_loss = 0.993080   max_val_acc = 0.994810
# Duration: 0:00:16.377420
# m3s5f5   min_val_loss = 0.003811   val_acc_when_min_loss = 0.998267   max_val_acc = 1.000000
# Duration: 0:00:16.966680
# Average min val loss:  0.0161360255908221   Average val accuracy when min loss:  0.994809091091156   Average max val accuracy:  0.994809091091156
#
#
# Model number: 3   Series size: 10
# m3s10f1   min_val_loss = 0.000087   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:15.501084
# m3s10f2   min_val_loss = 0.000742   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:15.515734
# m3s10f3   min_val_loss = 0.000318   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:16.327448
# m3s10f4   min_val_loss = 0.001315   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:15.386583
# m3s10f5   min_val_loss = 0.008630   val_acc_when_min_loss = 0.997872   max_val_acc = 0.997872
# Duration: 0:00:16.022326
# Average min val loss:  0.0022182720742421223   Average val accuracy when min loss:  0.9995744705200196   Average max val accuracy:  0.9995744705200196
#
#
# Model number: 3   Series size: 31
# m3s31f1   min_val_loss = 0.001064   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.540531
# m3s31f2   min_val_loss = 0.026849   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:06.153129
# m3s31f3   min_val_loss = 0.001343   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.602550
# m3s31f4   min_val_loss = 0.001223   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:06.007909
# m3s31f5   min_val_loss = 0.000948   val_acc_when_min_loss = 1.000000   max_val_acc = 1.000000
# Duration: 0:00:05.601502
# Average min val loss:  0.006285451329313218   Average val accuracy when min loss:  1.0   Average max val accuracy:  1.0

# %%
print(history[0][0].keys())
# Out:
# dict_keys(['loss', 'accuracy', 'auc', 'precision', 'recall', 'val_loss', 'val_accuracy', 'val_auc', 'val_precision', 'val_recall'])

# %%
pickle.dump(title, open(TRAIN_RESULTS_DIR + 'title.p', 'wb'))
pickle.dump(params, open(TRAIN_RESULTS_DIR + 'params.p', 'wb'))
pickle.dump(avg, open(TRAIN_RESULTS_DIR + 'avg.p', 'wb'))
pickle.dump(desc, open(TRAIN_RESULTS_DIR+ 'desc.p', 'wb'))
pickle.dump(history, open(TRAIN_RESULTS_DIR + 'history.p', 'wb'))
pickle.dump(conf_mat, open(TRAIN_RESULTS_DIR + 'conf_mat.p', 'wb'))
